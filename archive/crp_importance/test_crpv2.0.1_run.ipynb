# %%
import torch
import torchvision.transforms as T
from torchvision.models.vgg import vgg16_bn
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
# Importer ZennitCRP
from zennit.composites import EpsilonPlusFlat
from zennit.canonizers import SequentialMergeBatchNorm
from crp.attribution import CondAttribution
from crp.helper import get_layer_names
from crp.concepts import ChannelConcept

# %%
import torch
from torchvision.models.vgg import vgg16_bn
import torchvision.transforms as T
from PIL import Image

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = vgg16_bn(True).to(device)
model.eval()

transform = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# /home/timotheewsl/PER/Guillaume/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /home/timotheewsl/PER/Guillaume/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_BN_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_BN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import math

def betterPrintHeatmap(heatmaps):
    heatmaps = [h.detach().cpu().numpy() for h in heatmaps[:10]]
    number_line = math.ceil(len(heatmaps) / 5)
    fig, axes = plt.subplots(number_line, 6, figsize=(18, 6))

    vmin = min(h.min() for h in heatmaps)
    vmax = max(h.max() for h in heatmaps)
    print(f"Min value for a pixel: {vmin}, Max value for a pixel: {vmax}")
    heatmap_element = 0
    for i, ax in enumerate(axes.flat):
        row, col = divmod(i, 6)
        if heatmap_element >= len(heatmaps):
            ax.axis("off")
            continue
        if col > 4:
            ax.axis("off")
            continue
        im = ax.imshow(heatmaps[heatmap_element], cmap="seismic", interpolation="nearest", vmin=vmin, vmax=vmax)
        ax.set_title(f"Heatmap {heatmap_element+1}")
        heatmap_element += 1


    # Ajouter une barre de couleur verticale à droite de la grille
    fig.colorbar(im, ax=axes, orientation='vertical', location='right')

    # Ajuster l'espacement pour que les heatmaps ne se chevauchent pas
    plt.subplots_adjust(wspace=0.3, hspace=0.3)

    # Afficher la grille
    plt.show()

# %%
def compute_feature_importance(model, input_tensor, layer_idx, allFeaturesIDX, pred_class):
    """
    Calcule l'importance globale des features d'une couche donnée pour une classe prédite
    après désactivation de toutes les features spécifiées dans allFeaturesIDX.

    Arguments :
    - model : le modèle VGG16
    - input_tensor : l'image d'entrée sous forme de tenseur
    - layer_idx : l'index de la couche (ex : 40)
    - allFeaturesIDX : liste des indices des features à désactiver (list)
    - pred_class : la classe prédite initialement

    Retourne :
    - La différence entre le score original et le score après désactivation
    """

    # Obtenir la probabilité originale de la classe prédite
    with torch.no_grad():
        output_original = model(input_tensor)
        probs_original = torch.nn.functional.softmax(output_original, dim=1)
        original_score = probs_original[0, pred_class].item()

    def zero_out_features(module, input, output):
        for idx in allFeaturesIDX:
            output[:, idx, :, :] = 0  # Désactiver chaque feature spécifiée
        return output

    # Ajouter un hook temporaire
    hook = model.features[layer_idx].register_forward_hook(zero_out_features)

    # Faire une prédiction avec les features désactivées
    with torch.no_grad():
        output_disabled = model(input_tensor)
        probs_disabled = torch.nn.functional.softmax(output_disabled, dim=1)
        new_score = probs_disabled[0, pred_class].item()

    # Supprimer le hook
    hook.remove()

    # Calcul de l'importance globale des features désactivées
    importance = original_score - new_score
    print(original_score)
    print(new_score)
    print(f"Importance globale après désactivation des features : {importance:.4f}")

    return importance

# %%
import torch
from torchvision.models.vgg import vgg16_bn

def compute_feature_importance_all_input_tensor(model, all_imput_tensor_of_path, layer_idx, num_features, pred_class):
    sum_original_score = 0
    mean_original_score = 0
    feature_score = {}
    feature_importance = {}
    for _, tuple_input_pred_prob in all_imput_tensor_of_path.items() :
        input_tensor = tuple_input_pred_prob[0]
        with torch.no_grad():
            output_original = model(input_tensor)
            probs_original = torch.nn.functional.softmax(output_original, dim=1)
            original_score = probs_original[0, pred_class].item()
            sum_original_score += original_score
    mean_original_score = sum_original_score / len(all_imput_tensor_of_path)

    for feature_idx in range(num_features):
        def zero_out_feature(module, input, output, feature_idx=feature_idx):
            output[:, feature_idx, :, :] = 0  # Désactiver la feature
            return output

        hook = model.features[layer_idx].register_forward_hook(zero_out_feature)

        sum_new_score = 0
        mean_new_score = 0
        for _, tuple_input_pred_prob in all_imput_tensor_of_path.items():
            input_tensor = tuple_input_pred_prob[0]
            with torch.no_grad():
                output_disabled = model(input_tensor)
                probs_disabled = torch.nn.functional.softmax(output_disabled, dim=1)
                new_score = probs_disabled[0, pred_class].item()
                sum_new_score += new_score
        mean_new_score = sum_new_score / len(all_imput_tensor_of_path)
        hook.remove()

        feature_score[feature_idx] = mean_new_score

        # Affichage de progression
        importance = mean_original_score - mean_new_score
        feature_importance[feature_idx] = importance
        print(f"Feature {feature_idx+1}/{num_features} - Importance: {importance:.4f}")

    sorted_importance = dict(sorted(feature_importance.items(), key=lambda item: item[1], reverse=True))

    return sorted_importance, mean_original_score, feature_score

# %%
def load_images(folder_path):
    all_imput_tensor_of_path = {}
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpeg"):
            image_path = os.path.join(folder_path, filename)

            image = Image.open(image_path).convert("RGB")
            input_tensor = transform(image).unsqueeze(0).to(device)
            all_imput_tensor_of_path[filename] = input_tensor
            #print(f"Image {filename} chargée et transformée.")
    return all_imput_tensor_of_path

# %%
def separate_well_bad_predicted(all_imput_tensor_of_path, expected_class):
    all_wrong_predicted = {}
    all_well_predicted = {}
    for name, input_tensor in all_imput_tensor_of_path.items() :
        with torch.no_grad():
            output_original = model(input_tensor)
            pred_class = torch.argmax(output_original, dim=1).item()
            probs_original = torch.nn.functional.softmax(output_original, dim=1)
            original_score = probs_original[0, pred_class].item()
        if pred_class != expected_class :
            all_wrong_predicted[name] = (input_tensor, pred_class, original_score)
            continue
        all_well_predicted[name] = (input_tensor, pred_class, original_score)
    print(f"Nombre d'images mal prédites : {len(all_wrong_predicted)}")
    return all_wrong_predicted, all_well_predicted

# %%
def positive_negative_features(importance_dict):
    positiveFeatures = []
    negativeFeatures = []

    for feature, importance in importance_dict.items():
        if importance >= 0:
            positiveFeatures.append(feature)
        elif importance < 0:
            negativeFeatures.append(feature)

    print(f"Il y a {len(positiveFeatures)} features positives et {len(negativeFeatures)} features négatives.")
    return positiveFeatures, negativeFeatures

# %%
folder_path_toucan = r"/home/timotheewsl/PER/Guillaume/data/train/n01843383" #toucan
folder_path_hornbill = r"/home/timotheewsl/PER/Guillaume/data/train/n01829413"#hornbill

# %%
expected_class_toucan = 96
expected_class_hornbill = 93

# %%
all_imput_tensor_of_path_toucan = load_images(folder_path_toucan)
all_imput_tensor_of_path_hornbill = load_images(folder_path_hornbill)

# %%
all_wrong_predicted_toucan, all_well_predicted_toucan = separate_well_bad_predicted(all_imput_tensor_of_path_toucan, expected_class_toucan)
all_wrong_predicted_hornbill, all_well_predicted_hornbill = separate_well_bad_predicted(all_imput_tensor_of_path_hornbill, expected_class_hornbill)
# Out:
# Nombre d'images mal prédites : 35
# Nombre d'images mal prédites : 52

# %%
importance_dict_toucan, mean_original_score_toucan, feature_score_toucan = compute_feature_importance_all_input_tensor(model, all_well_predicted_toucan, layer_idx=40, num_features=512, pred_class=expected_class_toucan)
# Out:
# Feature 1/512 - Importance: -0.0002
# Feature 2/512 - Importance: 0.0002
# Feature 3/512 - Importance: -0.0007
# Feature 4/512 - Importance: -0.0011
# Feature 5/512 - Importance: 0.0003
# Feature 6/512 - Importance: -0.0002
# Feature 7/512 - Importance: -0.0001
# Feature 8/512 - Importance: 0.0006
# Feature 9/512 - Importance: -0.0001
# Feature 10/512 - Importance: -0.0008
# Feature 11/512 - Importance: -0.0015
# Feature 12/512 - Importance: -0.0003
# Feature 13/512 - Importance: -0.0011
# Feature 14/512 - Importance: -0.0016
# Feature 15/512 - Importance: 0.0005
# Feature 16/512 - Importance: 0.0026
# Feature 17/512 - Importance: -0.0013
# Feature 18/512 - Importance: -0.0002
# Feature 19/512 - Importance: 0.0006
# Feature 20/512 - Importance: -0.0018
# Feature 21/512 - Importance: 0.0001
# Feature 22/512 - Importance: -0.0009
# Feature 23/512 - Importance: -0.0004
# Feature 24/512 - Importance: 0.0000
# Feature 25/512 - Importance: 0.0015
# Feature 26/512 - Importance: 0.0001
# Feature 27/512 - Importance: -0.0001
# Feature 28/512 - Importance: 0.0012
# Feature 29/512 - Importance: -0.0002
# Feature 30/512 - Importance: 0.0004
# Feature 31/512 - Importance: 0.0010
# Feature 32/512 - Importance: 0.0002
# Feature 33/512 - Importance: 0.0004
# Feature 34/512 - Importance: 0.0008
# Feature 35/512 - Importance: 0.0014
# Feature 36/512 - Importance: 0.0005
# Feature 37/512 - Importance: 0.0001
# Feature 38/512 - Importance: 0.0006
# Feature 39/512 - Importance: 0.0001
# Feature 40/512 - Importance: 0.0020
# Feature 41/512 - Importance: 0.0000
# Feature 42/512 - Importance: -0.0013
# Feature 43/512 - Importance: 0.0009
# Feature 44/512 - Importance: 0.0003
# Feature 45/512 - Importance: 0.0019
# Feature 46/512 - Importance: -0.0011
# Feature 47/512 - Importance: -0.0010
# Feature 48/512 - Importance: 0.0006
# Feature 49/512 - Importance: 0.0002
# Feature 50/512 - Importance: -0.0001
# Feature 51/512 - Importance: -0.0001
# Feature 52/512 - Importance: 0.0001
# Feature 53/512 - Importance: -0.0008
# Feature 54/512 - Importance: 0.0000
# Feature 55/512 - Importance: 0.0001
# Feature 56/512 - Importance: 0.0002
# Feature 57/512 - Importance: 0.0001
# Feature 58/512 - Importance: 0.0014
# Feature 59/512 - Importance: 0.0004
# Feature 60/512 - Importance: -0.0053
# Feature 61/512 - Importance: 0.0020
# Feature 62/512 - Importance: -0.0005
# Feature 63/512 - Importance: 0.0004
# Feature 64/512 - Importance: 0.0000
# Feature 65/512 - Importance: -0.0005
# Feature 66/512 - Importance: 0.0025
# Feature 67/512 - Importance: 0.0009
# Feature 68/512 - Importance: -0.0002
# Feature 69/512 - Importance: 0.0009
# Feature 70/512 - Importance: 0.0001
# Feature 71/512 - Importance: -0.0001
# Feature 72/512 - Importance: -0.0012
# Feature 73/512 - Importance: -0.0014
# Feature 74/512 - Importance: -0.0002
# Feature 75/512 - Importance: 0.0015
# Feature 76/512 - Importance: -0.0009
# Feature 77/512 - Importance: 0.0006
# Feature 78/512 - Importance: -0.0020
# Feature 79/512 - Importance: -0.0001
# Feature 80/512 - Importance: -0.0011
# Feature 81/512 - Importance: -0.0002
# Feature 82/512 - Importance: -0.0002
# Feature 83/512 - Importance: 0.0002
# Feature 84/512 - Importance: 0.0023
# Feature 85/512 - Importance: -0.0016
# Feature 86/512 - Importance: -0.0008
# Feature 87/512 - Importance: 0.0016
# Feature 88/512 - Importance: 0.0004
# Feature 89/512 - Importance: -0.0005
# Feature 90/512 - Importance: -0.0001
# Feature 91/512 - Importance: 0.0006
# Feature 92/512 - Importance: 0.0009
# Feature 93/512 - Importance: -0.0003
# Feature 94/512 - Importance: 0.0000
# Feature 95/512 - Importance: -0.0025
# Feature 96/512 - Importance: -0.0001
# Feature 97/512 - Importance: 0.0017
# Feature 98/512 - Importance: 0.0001
# Feature 99/512 - Importance: 0.0000
# Feature 100/512 - Importance: -0.0002
# Feature 101/512 - Importance: -0.0005
# Feature 102/512 - Importance: 0.0014
# Feature 103/512 - Importance: -0.0007
# Feature 104/512 - Importance: -0.0009
# Feature 105/512 - Importance: 0.0001
# Feature 106/512 - Importance: 0.0004
# Feature 107/512 - Importance: 0.0003
# Feature 108/512 - Importance: 0.0005
# Feature 109/512 - Importance: -0.0012
# Feature 110/512 - Importance: -0.0006
# Feature 111/512 - Importance: 0.0000
# Feature 112/512 - Importance: 0.0014
# Feature 113/512 - Importance: 0.0085
# Feature 114/512 - Importance: -0.0001
# Feature 115/512 - Importance: -0.0006
# Feature 116/512 - Importance: 0.0014
# Feature 117/512 - Importance: 0.0024
# Feature 118/512 - Importance: 0.0003
# Feature 119/512 - Importance: -0.0005
# Feature 120/512 - Importance: 0.0029
# Feature 121/512 - Importance: -0.0002
# Feature 122/512 - Importance: 0.0030
# Feature 123/512 - Importance: 0.0000
# Feature 124/512 - Importance: -0.0003
# Feature 125/512 - Importance: -0.0003
# Feature 126/512 - Importance: 0.0028
# Feature 127/512 - Importance: -0.0004
# Feature 128/512 - Importance: -0.0004
# Feature 129/512 - Importance: 0.0002
# Feature 130/512 - Importance: 0.0001
# Feature 131/512 - Importance: 0.0004
# Feature 132/512 - Importance: -0.0017
# Feature 133/512 - Importance: 0.0002
# Feature 134/512 - Importance: 0.0010
# Feature 135/512 - Importance: 0.0008
# Feature 136/512 - Importance: 0.0000
# Feature 137/512 - Importance: -0.0000
# Feature 138/512 - Importance: 0.0005
# Feature 139/512 - Importance: -0.0020
# Feature 140/512 - Importance: 0.0026
# Feature 141/512 - Importance: 0.0024
# Feature 142/512 - Importance: 0.0016
# Feature 143/512 - Importance: -0.0006
# Feature 144/512 - Importance: -0.0008
# Feature 145/512 - Importance: 0.0006
# Feature 146/512 - Importance: 0.0024
# Feature 147/512 - Importance: 0.0013
# Feature 148/512 - Importance: -0.0021
# Feature 149/512 - Importance: 0.0000
# Feature 150/512 - Importance: 0.0034
# Feature 151/512 - Importance: 0.0009
# Feature 152/512 - Importance: 0.0003
# Feature 153/512 - Importance: 0.0022
# Feature 154/512 - Importance: 0.0028
# Feature 155/512 - Importance: 0.0021
# Feature 156/512 - Importance: 0.0022
# Feature 157/512 - Importance: -0.0001
# Feature 158/512 - Importance: 0.0004
# Feature 159/512 - Importance: 0.0001
# Feature 160/512 - Importance: 0.0027
# Feature 161/512 - Importance: -0.0001
# Feature 162/512 - Importance: 0.0036
# Feature 163/512 - Importance: -0.0007
# Feature 164/512 - Importance: -0.0003
# Feature 165/512 - Importance: -0.0009
# Feature 166/512 - Importance: 0.0018
# Feature 167/512 - Importance: 0.0006
# Feature 168/512 - Importance: 0.0002
# Feature 169/512 - Importance: 0.0008
# Feature 170/512 - Importance: -0.0029
# Feature 171/512 - Importance: -0.0001
# Feature 172/512 - Importance: 0.0010
# Feature 173/512 - Importance: 0.0016
# Feature 174/512 - Importance: -0.0005
# Feature 175/512 - Importance: -0.0004
# Feature 176/512 - Importance: -0.0000
# Feature 177/512 - Importance: -0.0003
# Feature 178/512 - Importance: 0.0002
# Feature 179/512 - Importance: -0.0016
# Feature 180/512 - Importance: -0.0001
# Feature 181/512 - Importance: -0.0001
# Feature 182/512 - Importance: 0.0023
# Feature 183/512 - Importance: 0.0007
# Feature 184/512 - Importance: -0.0007
# Feature 185/512 - Importance: 0.0024
# Feature 186/512 - Importance: -0.0000
# Feature 187/512 - Importance: 0.0010
# Feature 188/512 - Importance: 0.0008
# Feature 189/512 - Importance: 0.0003
# Feature 190/512 - Importance: -0.0009
# Feature 191/512 - Importance: -0.0000
# Feature 192/512 - Importance: 0.0018
# Feature 193/512 - Importance: 0.0004
# Feature 194/512 - Importance: -0.0007
# Feature 195/512 - Importance: 0.0034
# Feature 196/512 - Importance: -0.0022
# Feature 197/512 - Importance: 0.0002
# Feature 198/512 - Importance: -0.0011
# Feature 199/512 - Importance: -0.0004
# Feature 200/512 - Importance: -0.0009
# Feature 201/512 - Importance: 0.0014
# Feature 202/512 - Importance: -0.0003
# Feature 203/512 - Importance: -0.0000
# Feature 204/512 - Importance: -0.0003
# Feature 205/512 - Importance: 0.0002
# Feature 206/512 - Importance: -0.0005
# Feature 207/512 - Importance: -0.0009
# Feature 208/512 - Importance: 0.0021
# Feature 209/512 - Importance: -0.0003
# Feature 210/512 - Importance: 0.0012
# Feature 211/512 - Importance: -0.0009
# Feature 212/512 - Importance: 0.0007
# Feature 213/512 - Importance: -0.0004
# Feature 214/512 - Importance: 0.0001
# Feature 215/512 - Importance: -0.0021
# Feature 216/512 - Importance: -0.0003
# Feature 217/512 - Importance: 0.0001
# Feature 218/512 - Importance: -0.0002
# Feature 219/512 - Importance: 0.0003
# Feature 220/512 - Importance: -0.0004
# Feature 221/512 - Importance: -0.0014
# Feature 222/512 - Importance: 0.0003
# Feature 223/512 - Importance: -0.0006
# Feature 224/512 - Importance: -0.0010
# Feature 225/512 - Importance: -0.0010
# Feature 226/512 - Importance: 0.0021
# Feature 227/512 - Importance: 0.0040
# Feature 228/512 - Importance: -0.0001
# Feature 229/512 - Importance: -0.0000
# Feature 230/512 - Importance: -0.0008
# Feature 231/512 - Importance: -0.0013
# Feature 232/512 - Importance: -0.0003
# Feature 233/512 - Importance: 0.0006
# Feature 234/512 - Importance: 0.0015
# Feature 235/512 - Importance: 0.0004
# Feature 236/512 - Importance: 0.0004
# Feature 237/512 - Importance: 0.0017
# Feature 238/512 - Importance: -0.0003
# Feature 239/512 - Importance: -0.0000
# Feature 240/512 - Importance: -0.0020
# Feature 241/512 - Importance: -0.0000
# Feature 242/512 - Importance: -0.0003
# Feature 243/512 - Importance: 0.0025
# Feature 244/512 - Importance: 0.0081
# Feature 245/512 - Importance: 0.0001
# Feature 246/512 - Importance: -0.0001
# Feature 247/512 - Importance: 0.0015
# Feature 248/512 - Importance: -0.0008
# Feature 249/512 - Importance: -0.0000
# Feature 250/512 - Importance: 0.0001
# Feature 251/512 - Importance: -0.0010
# Feature 252/512 - Importance: 0.0004
# Feature 253/512 - Importance: -0.0004
# Feature 254/512 - Importance: 0.0007
# Feature 255/512 - Importance: -0.0002
# Feature 256/512 - Importance: 0.0005
# Feature 257/512 - Importance: -0.0006
# Feature 258/512 - Importance: 0.0004
# Feature 259/512 - Importance: -0.0006
# Feature 260/512 - Importance: -0.0007
# Feature 261/512 - Importance: -0.0004
# Feature 262/512 - Importance: -0.0005
# Feature 263/512 - Importance: 0.0006
# Feature 264/512 - Importance: 0.0000
# Feature 265/512 - Importance: -0.0020
# Feature 266/512 - Importance: 0.0004
# Feature 267/512 - Importance: 0.0052
# Feature 268/512 - Importance: -0.0026
# Feature 269/512 - Importance: -0.0000
# Feature 270/512 - Importance: 0.0017
# Feature 271/512 - Importance: 0.0003
# Feature 272/512 - Importance: 0.0030
# Feature 273/512 - Importance: 0.0001
# Feature 274/512 - Importance: -0.0001
# Feature 275/512 - Importance: -0.0005
# Feature 276/512 - Importance: 0.0003
# Feature 277/512 - Importance: 0.0002
# Feature 278/512 - Importance: 0.0002
# Feature 279/512 - Importance: -0.0008
# Feature 280/512 - Importance: -0.0015
# Feature 281/512 - Importance: 0.0000
# Feature 282/512 - Importance: 0.0002
# Feature 283/512 - Importance: 0.0038
# Feature 284/512 - Importance: 0.0003
# Feature 285/512 - Importance: -0.0006
# Feature 286/512 - Importance: 0.0012
# Feature 287/512 - Importance: -0.0000
# Feature 288/512 - Importance: -0.0001
# Feature 289/512 - Importance: -0.0015
# Feature 290/512 - Importance: -0.0004
# Feature 291/512 - Importance: -0.0022
# Feature 292/512 - Importance: 0.0004
# Feature 293/512 - Importance: 0.0004
# Feature 294/512 - Importance: -0.0003
# Feature 295/512 - Importance: -0.0021
# Feature 296/512 - Importance: -0.0011
# Feature 297/512 - Importance: 0.0001
# Feature 298/512 - Importance: -0.0000
# Feature 299/512 - Importance: 0.0009
# Feature 300/512 - Importance: -0.0005
# Feature 301/512 - Importance: 0.0005
# Feature 302/512 - Importance: 0.0002
# Feature 303/512 - Importance: -0.0001
# Feature 304/512 - Importance: 0.0012
# Feature 305/512 - Importance: 0.0018
# Feature 306/512 - Importance: 0.0007
# Feature 307/512 - Importance: 0.0004
# Feature 308/512 - Importance: 0.0004
# Feature 309/512 - Importance: -0.0005
# Feature 310/512 - Importance: 0.0000
# Feature 311/512 - Importance: 0.0003
# Feature 312/512 - Importance: 0.0005
# Feature 313/512 - Importance: 0.0008
# Feature 314/512 - Importance: 0.0002
# Feature 315/512 - Importance: -0.0001
# Feature 316/512 - Importance: -0.0025
# Feature 317/512 - Importance: 0.0020
# Feature 318/512 - Importance: -0.0002
# Feature 319/512 - Importance: 0.0026
# Feature 320/512 - Importance: -0.0045
# Feature 321/512 - Importance: 0.0000
# Feature 322/512 - Importance: -0.0018
# Feature 323/512 - Importance: -0.0010
# Feature 324/512 - Importance: -0.0003
# Feature 325/512 - Importance: -0.0001
# Feature 326/512 - Importance: 0.0005
# Feature 327/512 - Importance: -0.0002
# Feature 328/512 - Importance: -0.0005
# Feature 329/512 - Importance: 0.0006
# Feature 330/512 - Importance: -0.0007
# Feature 331/512 - Importance: -0.0001
# Feature 332/512 - Importance: 0.0006
# Feature 333/512 - Importance: 0.0002
# Feature 334/512 - Importance: 0.0008
# Feature 335/512 - Importance: -0.0005
# Feature 336/512 - Importance: -0.0001
# Feature 337/512 - Importance: -0.0004
# Feature 338/512 - Importance: 0.0007
# Feature 339/512 - Importance: -0.0003
# Feature 340/512 - Importance: 0.0031
# Feature 341/512 - Importance: 0.0001
# Feature 342/512 - Importance: 0.0000
# Feature 343/512 - Importance: -0.0003
# Feature 344/512 - Importance: -0.0013
# Feature 345/512 - Importance: 0.0000
# Feature 346/512 - Importance: -0.0000
# Feature 347/512 - Importance: -0.0008
# Feature 348/512 - Importance: 0.0001
# Feature 349/512 - Importance: -0.0000
# Feature 350/512 - Importance: 0.0023
# Feature 351/512 - Importance: 0.0017
# Feature 352/512 - Importance: 0.0006
# Feature 353/512 - Importance: -0.0003
# Feature 354/512 - Importance: -0.0008
# Feature 355/512 - Importance: -0.0008
# Feature 356/512 - Importance: 0.0007
# Feature 357/512 - Importance: -0.0008
# Feature 358/512 - Importance: 0.0001
# Feature 359/512 - Importance: -0.0013
# Feature 360/512 - Importance: -0.0003
# Feature 361/512 - Importance: -0.0005
# Feature 362/512 - Importance: -0.0006
# Feature 363/512 - Importance: 0.0025
# Feature 364/512 - Importance: -0.0001
# Feature 365/512 - Importance: -0.0007
# Feature 366/512 - Importance: -0.0007
# Feature 367/512 - Importance: -0.0001
# Feature 368/512 - Importance: 0.0006
# Feature 369/512 - Importance: 0.0020
# Feature 370/512 - Importance: -0.0007
# Feature 371/512 - Importance: 0.0007
# Feature 372/512 - Importance: -0.0000
# Feature 373/512 - Importance: 0.0011
# Feature 374/512 - Importance: 0.0011
# Feature 375/512 - Importance: -0.0009
# Feature 376/512 - Importance: -0.0006
# Feature 377/512 - Importance: 0.0026
# Feature 378/512 - Importance: 0.0004
# Feature 379/512 - Importance: 0.0043
# Feature 380/512 - Importance: -0.0006
# Feature 381/512 - Importance: 0.0039
# Feature 382/512 - Importance: 0.0001
# Feature 383/512 - Importance: -0.0017
# Feature 384/512 - Importance: -0.0014
# Feature 385/512 - Importance: -0.0015
# Feature 386/512 - Importance: -0.0011
# Feature 387/512 - Importance: 0.0001
# Feature 388/512 - Importance: 0.0007
# Feature 389/512 - Importance: 0.0086
# Feature 390/512 - Importance: -0.0003
# Feature 391/512 - Importance: 0.0006
# Feature 392/512 - Importance: 0.0008
# Feature 393/512 - Importance: 0.0006
# Feature 394/512 - Importance: -0.0003
# Feature 395/512 - Importance: 0.0001
# Feature 396/512 - Importance: -0.0002
# Feature 397/512 - Importance: 0.0007
# Feature 398/512 - Importance: -0.0004
# Feature 399/512 - Importance: 0.0005
# Feature 400/512 - Importance: 0.0005
# Feature 401/512 - Importance: 0.0009
# Feature 402/512 - Importance: 0.0026
# Feature 403/512 - Importance: 0.0009
# Feature 404/512 - Importance: 0.0000
# Feature 405/512 - Importance: 0.0013
# Feature 406/512 - Importance: 0.0024
# Feature 407/512 - Importance: 0.0029
# Feature 408/512 - Importance: 0.0001
# Feature 409/512 - Importance: 0.0004
# Feature 410/512 - Importance: -0.0013
# Feature 411/512 - Importance: 0.0000
# Feature 412/512 - Importance: -0.0005
# Feature 413/512 - Importance: -0.0001
# Feature 414/512 - Importance: -0.0019
# Feature 415/512 - Importance: -0.0012
# Feature 416/512 - Importance: -0.0008
# Feature 417/512 - Importance: 0.0010
# Feature 418/512 - Importance: 0.0003
# Feature 419/512 - Importance: -0.0003
# Feature 420/512 - Importance: 0.0051
# Feature 421/512 - Importance: 0.0009
# Feature 422/512 - Importance: 0.0002
# Feature 423/512 - Importance: -0.0003
# Feature 424/512 - Importance: -0.0011
# Feature 425/512 - Importance: 0.0002
# Feature 426/512 - Importance: -0.0010
# Feature 427/512 - Importance: 0.0000
# Feature 428/512 - Importance: -0.0001
# Feature 429/512 - Importance: -0.0015
# Feature 430/512 - Importance: -0.0017
# Feature 431/512 - Importance: 0.0007
# Feature 432/512 - Importance: 0.0032
# Feature 433/512 - Importance: 0.0002
# Feature 434/512 - Importance: -0.0002
# Feature 435/512 - Importance: -0.0017
# Feature 436/512 - Importance: 0.0004
# Feature 437/512 - Importance: -0.0020
# Feature 438/512 - Importance: -0.0001
# Feature 439/512 - Importance: -0.0006
# Feature 440/512 - Importance: 0.0009
# Feature 441/512 - Importance: 0.0003
# Feature 442/512 - Importance: 0.0005
# Feature 443/512 - Importance: 0.0007
# Feature 444/512 - Importance: -0.0005
# Feature 445/512 - Importance: 0.0038
# Feature 446/512 - Importance: -0.0008
# Feature 447/512 - Importance: 0.0001
# Feature 448/512 - Importance: 0.0009
# Feature 449/512 - Importance: 0.0004
# Feature 450/512 - Importance: -0.0019
# Feature 451/512 - Importance: -0.0007
# Feature 452/512 - Importance: -0.0028
# Feature 453/512 - Importance: 0.0002
# Feature 454/512 - Importance: -0.0013
# Feature 455/512 - Importance: -0.0024
# Feature 456/512 - Importance: -0.0004
# Feature 457/512 - Importance: -0.0003
# Feature 458/512 - Importance: 0.0004
# Feature 459/512 - Importance: -0.0002
# Feature 460/512 - Importance: -0.0000
# Feature 461/512 - Importance: -0.0003
# Feature 462/512 - Importance: -0.0001
# Feature 463/512 - Importance: 0.0009
# Feature 464/512 - Importance: 0.0071
# Feature 465/512 - Importance: 0.0008
# Feature 466/512 - Importance: -0.0015
# Feature 467/512 - Importance: -0.0015
# Feature 468/512 - Importance: -0.0001
# Feature 469/512 - Importance: 0.0003
# Feature 470/512 - Importance: 0.0011
# Feature 471/512 - Importance: 0.0006
# Feature 472/512 - Importance: 0.0000
# Feature 473/512 - Importance: 0.0010
# Feature 474/512 - Importance: -0.0001
# Feature 475/512 - Importance: 0.0004
# Feature 476/512 - Importance: -0.0003
# Feature 477/512 - Importance: 0.0049
# Feature 478/512 - Importance: 0.0017
# Feature 479/512 - Importance: 0.0000
# Feature 480/512 - Importance: -0.0009
# Feature 481/512 - Importance: -0.0023
# Feature 482/512 - Importance: -0.0003
# Feature 483/512 - Importance: 0.0021
# Feature 484/512 - Importance: 0.0013
# Feature 485/512 - Importance: 0.0013
# Feature 486/512 - Importance: -0.0001
# Feature 487/512 - Importance: -0.0001
# Feature 488/512 - Importance: 0.0003
# Feature 489/512 - Importance: 0.0038
# Feature 490/512 - Importance: 0.0005
# Feature 491/512 - Importance: -0.0014
# Feature 492/512 - Importance: -0.0000
# Feature 493/512 - Importance: -0.0001
# Feature 494/512 - Importance: 0.0000
# Feature 495/512 - Importance: -0.0002
# Feature 496/512 - Importance: 0.0039
# Feature 497/512 - Importance: 0.0001
# Feature 498/512 - Importance: -0.0003
# Feature 499/512 - Importance: 0.0016
# Feature 500/512 - Importance: -0.0012
# Feature 501/512 - Importance: 0.0018
# Feature 502/512 - Importance: 0.0012
# Feature 503/512 - Importance: 0.0003
# Feature 504/512 - Importance: 0.0001
# Feature 505/512 - Importance: 0.0014
# Feature 506/512 - Importance: -0.0005
# Feature 507/512 - Importance: 0.0004
# Feature 508/512 - Importance: 0.0001
# Feature 509/512 - Importance: -0.0012
# Feature 510/512 - Importance: -0.0005
# Feature 511/512 - Importance: -0.0004
# Feature 512/512 - Importance: 0.0013

# %%
importance_dict_hornbill, mean_original_score_hornbill, feature_score_hornbill = compute_feature_importance_all_input_tensor(model, all_well_predicted_hornbill, layer_idx=40, num_features=512, pred_class=expected_class_hornbill)
# Out:
# Feature 1/512 - Importance: -0.0006
# Feature 2/512 - Importance: 0.0027
# Feature 3/512 - Importance: -0.0006
# Feature 4/512 - Importance: 0.0024
# Feature 5/512 - Importance: 0.0023
# Feature 6/512 - Importance: -0.0001
# Feature 7/512 - Importance: -0.0004
# Feature 8/512 - Importance: -0.0011
# Feature 9/512 - Importance: -0.0008
# Feature 10/512 - Importance: 0.0022
# Feature 11/512 - Importance: 0.0027
# Feature 12/512 - Importance: -0.0009
# Feature 13/512 - Importance: 0.0011
# Feature 14/512 - Importance: 0.0008
# Feature 15/512 - Importance: 0.0049
# Feature 16/512 - Importance: 0.0070
# Feature 17/512 - Importance: 0.0017
# Feature 18/512 - Importance: -0.0002
# Feature 19/512 - Importance: 0.0044
# Feature 20/512 - Importance: 0.0102
# Feature 21/512 - Importance: -0.0001
# Feature 22/512 - Importance: 0.0001
# Feature 23/512 - Importance: -0.0007
# Feature 24/512 - Importance: -0.0000
# Feature 25/512 - Importance: -0.0013
# Feature 26/512 - Importance: 0.0001
# Feature 27/512 - Importance: 0.0001
# Feature 28/512 - Importance: 0.0001
# Feature 29/512 - Importance: -0.0004
# Feature 30/512 - Importance: -0.0030
# Feature 31/512 - Importance: 0.0007
# Feature 32/512 - Importance: -0.0002
# Feature 33/512 - Importance: -0.0003
# Feature 34/512 - Importance: 0.0010
# Feature 35/512 - Importance: -0.0015
# Feature 36/512 - Importance: -0.0010
# Feature 37/512 - Importance: -0.0002
# Feature 38/512 - Importance: 0.0001
# Feature 39/512 - Importance: -0.0012
# Feature 40/512 - Importance: -0.0009
# Feature 41/512 - Importance: 0.0000
# Feature 42/512 - Importance: 0.0082
# Feature 43/512 - Importance: -0.0036
# Feature 44/512 - Importance: -0.0010
# Feature 45/512 - Importance: 0.0049
# Feature 46/512 - Importance: 0.0048
# Feature 47/512 - Importance: 0.0040
# Feature 48/512 - Importance: -0.0004
# Feature 49/512 - Importance: -0.0005
# Feature 50/512 - Importance: -0.0010
# Feature 51/512 - Importance: -0.0002
# Feature 52/512 - Importance: 0.0039
# Feature 53/512 - Importance: 0.0030
# Feature 54/512 - Importance: -0.0008
# Feature 55/512 - Importance: 0.0003
# Feature 56/512 - Importance: -0.0024
# Feature 57/512 - Importance: -0.0001
# Feature 58/512 - Importance: -0.0022
# Feature 59/512 - Importance: -0.0003
# Feature 60/512 - Importance: -0.0022
# Feature 61/512 - Importance: 0.0059
# Feature 62/512 - Importance: 0.0001
# Feature 63/512 - Importance: 0.0030
# Feature 64/512 - Importance: -0.0000
# Feature 65/512 - Importance: -0.0016
# Feature 66/512 - Importance: -0.0012
# Feature 67/512 - Importance: -0.0001
# Feature 68/512 - Importance: -0.0004
# Feature 69/512 - Importance: -0.0029
# Feature 70/512 - Importance: -0.0012
# Feature 71/512 - Importance: 0.0004
# Feature 72/512 - Importance: -0.0028
# Feature 73/512 - Importance: -0.0016
# Feature 74/512 - Importance: 0.0001
# Feature 75/512 - Importance: 0.0002
# Feature 76/512 - Importance: 0.0000
# Feature 77/512 - Importance: -0.0013
# Feature 78/512 - Importance: 0.0023
# Feature 79/512 - Importance: 0.0007
# Feature 80/512 - Importance: 0.0013
# Feature 81/512 - Importance: 0.0002
# Feature 82/512 - Importance: 0.0038
# Feature 83/512 - Importance: -0.0034
# Feature 84/512 - Importance: 0.0011
# Feature 85/512 - Importance: 0.0007
# Feature 86/512 - Importance: -0.0005
# Feature 87/512 - Importance: -0.0005
# Feature 88/512 - Importance: 0.0006
# Feature 89/512 - Importance: 0.0033
# Feature 90/512 - Importance: 0.0028
# Feature 91/512 - Importance: -0.0022
# Feature 92/512 - Importance: -0.0011
# Feature 93/512 - Importance: -0.0003
# Feature 94/512 - Importance: -0.0012
# Feature 95/512 - Importance: 0.0374
# Feature 96/512 - Importance: 0.0004
# Feature 97/512 - Importance: -0.0013
# Feature 98/512 - Importance: 0.0007
# Feature 99/512 - Importance: 0.0007
# Feature 100/512 - Importance: 0.0007
# Feature 101/512 - Importance: 0.0003
# Feature 102/512 - Importance: 0.0013
# Feature 103/512 - Importance: 0.0012
# Feature 104/512 - Importance: -0.0025
# Feature 105/512 - Importance: 0.0061
# Feature 106/512 - Importance: -0.0003
# Feature 107/512 - Importance: 0.0011
# Feature 108/512 - Importance: 0.0002
# Feature 109/512 - Importance: -0.0001
# Feature 110/512 - Importance: -0.0001
# Feature 111/512 - Importance: -0.0008
# Feature 112/512 - Importance: 0.0021
# Feature 113/512 - Importance: -0.0022
# Feature 114/512 - Importance: 0.0000
# Feature 115/512 - Importance: 0.0022
# Feature 116/512 - Importance: -0.0015
# Feature 117/512 - Importance: -0.0033
# Feature 118/512 - Importance: -0.0004
# Feature 119/512 - Importance: 0.0015
# Feature 120/512 - Importance: -0.0054
# Feature 121/512 - Importance: -0.0000
# Feature 122/512 - Importance: 0.0043
# Feature 123/512 - Importance: 0.0000
# Feature 124/512 - Importance: -0.0001
# Feature 125/512 - Importance: -0.0005
# Feature 126/512 - Importance: 0.0000
# Feature 127/512 - Importance: 0.0003
# Feature 128/512 - Importance: -0.0021
# Feature 129/512 - Importance: -0.0003
# Feature 130/512 - Importance: 0.0008
# Feature 131/512 - Importance: -0.0021
# Feature 132/512 - Importance: -0.0007
# Feature 133/512 - Importance: -0.0009
# Feature 134/512 - Importance: -0.0007
# Feature 135/512 - Importance: -0.0001
# Feature 136/512 - Importance: 0.0002
# Feature 137/512 - Importance: 0.0006
# Feature 138/512 - Importance: -0.0009
# Feature 139/512 - Importance: 0.0055
# Feature 140/512 - Importance: 0.0022
# Feature 141/512 - Importance: -0.0040
# Feature 142/512 - Importance: -0.0029
# Feature 143/512 - Importance: -0.0043
# Feature 144/512 - Importance: 0.0006
# Feature 145/512 - Importance: -0.0015
# Feature 146/512 - Importance: -0.0011
# Feature 147/512 - Importance: -0.0003
# Feature 148/512 - Importance: -0.0009
# Feature 149/512 - Importance: -0.0004
# Feature 150/512 - Importance: 0.0020
# Feature 151/512 - Importance: -0.0019
# Feature 152/512 - Importance: -0.0009
# Feature 153/512 - Importance: 0.0004
# Feature 154/512 - Importance: 0.0077
# Feature 155/512 - Importance: 0.0017
# Feature 156/512 - Importance: 0.0037
# Feature 157/512 - Importance: -0.0001
# Feature 158/512 - Importance: 0.0004
# Feature 159/512 - Importance: -0.0005
# Feature 160/512 - Importance: 0.0014
# Feature 161/512 - Importance: 0.0003
# Feature 162/512 - Importance: -0.0026
# Feature 163/512 - Importance: 0.0070
# Feature 164/512 - Importance: 0.0054
# Feature 165/512 - Importance: 0.0006
# Feature 166/512 - Importance: -0.0011
# Feature 167/512 - Importance: -0.0014
# Feature 168/512 - Importance: 0.0011
# Feature 169/512 - Importance: 0.0040
# Feature 170/512 - Importance: -0.0044
# Feature 171/512 - Importance: -0.0002
# Feature 172/512 - Importance: -0.0000
# Feature 173/512 - Importance: 0.0027
# Feature 174/512 - Importance: 0.0011
# Feature 175/512 - Importance: 0.0020
# Feature 176/512 - Importance: -0.0000
# Feature 177/512 - Importance: 0.0002
# Feature 178/512 - Importance: -0.0008
# Feature 179/512 - Importance: 0.0027
# Feature 180/512 - Importance: 0.0015
# Feature 181/512 - Importance: -0.0005
# Feature 182/512 - Importance: -0.0014
# Feature 183/512 - Importance: -0.0058
# Feature 184/512 - Importance: 0.0007
# Feature 185/512 - Importance: 0.0032
# Feature 186/512 - Importance: -0.0000
# Feature 187/512 - Importance: 0.0016
# Feature 188/512 - Importance: -0.0005
# Feature 189/512 - Importance: 0.0007
# Feature 190/512 - Importance: -0.0013
# Feature 191/512 - Importance: -0.0002
# Feature 192/512 - Importance: 0.0012
# Feature 193/512 - Importance: 0.0004
# Feature 194/512 - Importance: 0.0016
# Feature 195/512 - Importance: 0.0003
# Feature 196/512 - Importance: 0.0069
# Feature 197/512 - Importance: 0.0040
# Feature 198/512 - Importance: 0.0029
# Feature 199/512 - Importance: -0.0025
# Feature 200/512 - Importance: 0.0001
# Feature 201/512 - Importance: 0.0056
# Feature 202/512 - Importance: -0.0005
# Feature 203/512 - Importance: -0.0003
# Feature 204/512 - Importance: 0.0061
# Feature 205/512 - Importance: 0.0002
# Feature 206/512 - Importance: 0.0036
# Feature 207/512 - Importance: 0.0005
# Feature 208/512 - Importance: -0.0030
# Feature 209/512 - Importance: 0.0011
# Feature 210/512 - Importance: -0.0016
# Feature 211/512 - Importance: 0.0048
# Feature 212/512 - Importance: 0.0026
# Feature 213/512 - Importance: -0.0000
# Feature 214/512 - Importance: -0.0004
# Feature 215/512 - Importance: -0.0005
# Feature 216/512 - Importance: -0.0005
# Feature 217/512 - Importance: -0.0000
# Feature 218/512 - Importance: -0.0004
# Feature 219/512 - Importance: -0.0010
# Feature 220/512 - Importance: -0.0020
# Feature 221/512 - Importance: 0.0021
# Feature 222/512 - Importance: -0.0002
# Feature 223/512 - Importance: -0.0000
# Feature 224/512 - Importance: 0.0000
# Feature 225/512 - Importance: -0.0015
# Feature 226/512 - Importance: -0.0002
# Feature 227/512 - Importance: 0.0067
# Feature 228/512 - Importance: -0.0009
# Feature 229/512 - Importance: -0.0004
# Feature 230/512 - Importance: 0.0051
# Feature 231/512 - Importance: 0.0014
# Feature 232/512 - Importance: 0.0003
# Feature 233/512 - Importance: -0.0016
# Feature 234/512 - Importance: -0.0017
# Feature 235/512 - Importance: 0.0014
# Feature 236/512 - Importance: -0.0010
# Feature 237/512 - Importance: -0.0028
# Feature 238/512 - Importance: 0.0010
# Feature 239/512 - Importance: -0.0002
# Feature 240/512 - Importance: 0.0025
# Feature 241/512 - Importance: 0.0001
# Feature 242/512 - Importance: -0.0014
# Feature 243/512 - Importance: -0.0016
# Feature 244/512 - Importance: -0.0050
# Feature 245/512 - Importance: -0.0001
# Feature 246/512 - Importance: 0.0011
# Feature 247/512 - Importance: 0.0029
# Feature 248/512 - Importance: 0.0002
# Feature 249/512 - Importance: 0.0003
# Feature 250/512 - Importance: 0.0025
# Feature 251/512 - Importance: 0.0044
# Feature 252/512 - Importance: -0.0009
# Feature 253/512 - Importance: 0.0008
# Feature 254/512 - Importance: -0.0005
# Feature 255/512 - Importance: -0.0024
# Feature 256/512 - Importance: 0.0023
# Feature 257/512 - Importance: 0.0034
# Feature 258/512 - Importance: 0.0016
# Feature 259/512 - Importance: -0.0007
# Feature 260/512 - Importance: 0.0023
# Feature 261/512 - Importance: -0.0005
# Feature 262/512 - Importance: -0.0000
# Feature 263/512 - Importance: -0.0013
# Feature 264/512 - Importance: -0.0037
# Feature 265/512 - Importance: -0.0016
# Feature 266/512 - Importance: -0.0018
# Feature 267/512 - Importance: -0.0002
# Feature 268/512 - Importance: 0.0068
# Feature 269/512 - Importance: -0.0001
# Feature 270/512 - Importance: 0.0001
# Feature 271/512 - Importance: -0.0000
# Feature 272/512 - Importance: 0.0003
# Feature 273/512 - Importance: 0.0003
# Feature 274/512 - Importance: -0.0001
# Feature 275/512 - Importance: -0.0017
# Feature 276/512 - Importance: -0.0011
# Feature 277/512 - Importance: 0.0023
# Feature 278/512 - Importance: -0.0008
# Feature 279/512 - Importance: 0.0002
# Feature 280/512 - Importance: -0.0007
# Feature 281/512 - Importance: 0.0003
# Feature 282/512 - Importance: 0.0002
# Feature 283/512 - Importance: -0.0019
# Feature 284/512 - Importance: 0.0013
# Feature 285/512 - Importance: 0.0002
# Feature 286/512 - Importance: -0.0013
# Feature 287/512 - Importance: 0.0012
# Feature 288/512 - Importance: 0.0045
# Feature 289/512 - Importance: 0.0269
# Feature 290/512 - Importance: -0.0018
# Feature 291/512 - Importance: 0.0009
# Feature 292/512 - Importance: -0.0015
# Feature 293/512 - Importance: -0.0002
# Feature 294/512 - Importance: -0.0003
# Feature 295/512 - Importance: 0.0012
# Feature 296/512 - Importance: 0.0034
# Feature 297/512 - Importance: 0.0010
# Feature 298/512 - Importance: 0.0001
# Feature 299/512 - Importance: 0.0000
# Feature 300/512 - Importance: 0.0021
# Feature 301/512 - Importance: -0.0021
# Feature 302/512 - Importance: 0.0004
# Feature 303/512 - Importance: 0.0003
# Feature 304/512 - Importance: -0.0004
# Feature 305/512 - Importance: -0.0003
# Feature 306/512 - Importance: 0.0024
# Feature 307/512 - Importance: -0.0005
# Feature 308/512 - Importance: -0.0004
# Feature 309/512 - Importance: -0.0010
# Feature 310/512 - Importance: -0.0001
# Feature 311/512 - Importance: 0.0023
# Feature 312/512 - Importance: 0.0013
# Feature 313/512 - Importance: 0.0002
# Feature 314/512 - Importance: 0.0007
# Feature 315/512 - Importance: 0.0036
# Feature 316/512 - Importance: 0.0016
# Feature 317/512 - Importance: -0.0007
# Feature 318/512 - Importance: -0.0012
# Feature 319/512 - Importance: 0.0041
# Feature 320/512 - Importance: 0.0047
# Feature 321/512 - Importance: -0.0007
# Feature 322/512 - Importance: 0.0019
# Feature 323/512 - Importance: 0.0001
# Feature 324/512 - Importance: 0.0008
# Feature 325/512 - Importance: -0.0002
# Feature 326/512 - Importance: 0.0013
# Feature 327/512 - Importance: 0.0031
# Feature 328/512 - Importance: 0.0022
# Feature 329/512 - Importance: 0.0004
# Feature 330/512 - Importance: -0.0012
# Feature 331/512 - Importance: 0.0031
# Feature 332/512 - Importance: 0.0002
# Feature 333/512 - Importance: 0.0007
# Feature 334/512 - Importance: -0.0011
# Feature 335/512 - Importance: 0.0028
# Feature 336/512 - Importance: -0.0005
# Feature 337/512 - Importance: 0.0005
# Feature 338/512 - Importance: 0.0010
# Feature 339/512 - Importance: 0.0014
# Feature 340/512 - Importance: -0.0041
# Feature 341/512 - Importance: 0.0072
# Feature 342/512 - Importance: -0.0015
# Feature 343/512 - Importance: 0.0005
# Feature 344/512 - Importance: 0.0002
# Feature 345/512 - Importance: 0.0012
# Feature 346/512 - Importance: 0.0001
# Feature 347/512 - Importance: -0.0005
# Feature 348/512 - Importance: -0.0008
# Feature 349/512 - Importance: -0.0010
# Feature 350/512 - Importance: -0.0061
# Feature 351/512 - Importance: -0.0018
# Feature 352/512 - Importance: 0.0033
# Feature 353/512 - Importance: 0.0001
# Feature 354/512 - Importance: 0.0002
# Feature 355/512 - Importance: -0.0040
# Feature 356/512 - Importance: 0.0010
# Feature 357/512 - Importance: 0.0012
# Feature 358/512 - Importance: 0.0001
# Feature 359/512 - Importance: -0.0005
# Feature 360/512 - Importance: 0.0004
# Feature 361/512 - Importance: 0.0004
# Feature 362/512 - Importance: -0.0008
# Feature 363/512 - Importance: -0.0007
# Feature 364/512 - Importance: -0.0003
# Feature 365/512 - Importance: 0.0001
# Feature 366/512 - Importance: 0.0009
# Feature 367/512 - Importance: 0.0004
# Feature 368/512 - Importance: 0.0014
# Feature 369/512 - Importance: -0.0034
# Feature 370/512 - Importance: 0.0014
# Feature 371/512 - Importance: -0.0032
# Feature 372/512 - Importance: -0.0011
# Feature 373/512 - Importance: -0.0032
# Feature 374/512 - Importance: -0.0017
# Feature 375/512 - Importance: 0.0030
# Feature 376/512 - Importance: 0.0015
# Feature 377/512 - Importance: -0.0013
# Feature 378/512 - Importance: 0.0048
# Feature 379/512 - Importance: -0.0026
# Feature 380/512 - Importance: -0.0004
# Feature 381/512 - Importance: 0.0022
# Feature 382/512 - Importance: 0.0003
# Feature 383/512 - Importance: -0.0013
# Feature 384/512 - Importance: -0.0025
# Feature 385/512 - Importance: 0.0015
# Feature 386/512 - Importance: 0.0007
# Feature 387/512 - Importance: -0.0015
# Feature 388/512 - Importance: -0.0013
# Feature 389/512 - Importance: -0.0074
# Feature 390/512 - Importance: 0.0007
# Feature 391/512 - Importance: -0.0014
# Feature 392/512 - Importance: -0.0021
# Feature 393/512 - Importance: 0.0004
# Feature 394/512 - Importance: -0.0006
# Feature 395/512 - Importance: -0.0047
# Feature 396/512 - Importance: 0.0004
# Feature 397/512 - Importance: -0.0015
# Feature 398/512 - Importance: 0.0005
# Feature 399/512 - Importance: 0.0022
# Feature 400/512 - Importance: 0.0027
# Feature 401/512 - Importance: -0.0009
# Feature 402/512 - Importance: -0.0008
# Feature 403/512 - Importance: 0.0012
# Feature 404/512 - Importance: -0.0011
# Feature 405/512 - Importance: -0.0015
# Feature 406/512 - Importance: -0.0001
# Feature 407/512 - Importance: -0.0005
# Feature 408/512 - Importance: -0.0001
# Feature 409/512 - Importance: -0.0005
# Feature 410/512 - Importance: 0.0013
# Feature 411/512 - Importance: -0.0029
# Feature 412/512 - Importance: 0.0016
# Feature 413/512 - Importance: 0.0016
# Feature 414/512 - Importance: -0.0020
# Feature 415/512 - Importance: -0.0031
# Feature 416/512 - Importance: 0.0001
# Feature 417/512 - Importance: -0.0022
# Feature 418/512 - Importance: 0.0008
# Feature 419/512 - Importance: 0.0022
# Feature 420/512 - Importance: -0.0065
# Feature 421/512 - Importance: 0.0000
# Feature 422/512 - Importance: 0.0006
# Feature 423/512 - Importance: -0.0009
# Feature 424/512 - Importance: -0.0037
# Feature 425/512 - Importance: -0.0009
# Feature 426/512 - Importance: -0.0020
# Feature 427/512 - Importance: -0.0003
# Feature 428/512 - Importance: -0.0003
# Feature 429/512 - Importance: -0.0098
# Feature 430/512 - Importance: -0.0030
# Feature 431/512 - Importance: 0.0009
# Feature 432/512 - Importance: -0.0044
# Feature 433/512 - Importance: 0.0042
# Feature 434/512 - Importance: -0.0020
# Feature 435/512 - Importance: 0.0013
# Feature 436/512 - Importance: -0.0005
# Feature 437/512 - Importance: -0.0017
# Feature 438/512 - Importance: 0.0005
# Feature 439/512 - Importance: -0.0013
# Feature 440/512 - Importance: -0.0008
# Feature 441/512 - Importance: 0.0000
# Feature 442/512 - Importance: -0.0044
# Feature 443/512 - Importance: 0.0037
# Feature 444/512 - Importance: -0.0021
# Feature 445/512 - Importance: -0.0040
# Feature 446/512 - Importance: 0.0015
# Feature 447/512 - Importance: 0.0001
# Feature 448/512 - Importance: -0.0000
# Feature 449/512 - Importance: -0.0014
# Feature 450/512 - Importance: 0.0080
# Feature 451/512 - Importance: -0.0021
# Feature 452/512 - Importance: -0.0005
# Feature 453/512 - Importance: -0.0001
# Feature 454/512 - Importance: 0.0024
# Feature 455/512 - Importance: -0.0007
# Feature 456/512 - Importance: 0.0009
# Feature 457/512 - Importance: -0.0001
# Feature 458/512 - Importance: -0.0025
# Feature 459/512 - Importance: 0.0003
# Feature 460/512 - Importance: -0.0006
# Feature 461/512 - Importance: 0.0010
# Feature 462/512 - Importance: 0.0016
# Feature 463/512 - Importance: -0.0026
# Feature 464/512 - Importance: -0.0005
# Feature 465/512 - Importance: -0.0020
# Feature 466/512 - Importance: 0.0035
# Feature 467/512 - Importance: -0.0006
# Feature 468/512 - Importance: 0.0008
# Feature 469/512 - Importance: -0.0003
# Feature 470/512 - Importance: 0.0031
# Feature 471/512 - Importance: -0.0022
# Feature 472/512 - Importance: 0.0003
# Feature 473/512 - Importance: -0.0008
# Feature 474/512 - Importance: -0.0004
# Feature 475/512 - Importance: 0.0012
# Feature 476/512 - Importance: -0.0011
# Feature 477/512 - Importance: 0.0000
# Feature 478/512 - Importance: 0.0017
# Feature 479/512 - Importance: -0.0006
# Feature 480/512 - Importance: -0.0017
# Feature 481/512 - Importance: 0.0061
# Feature 482/512 - Importance: -0.0002
# Feature 483/512 - Importance: -0.0023
# Feature 484/512 - Importance: 0.0009
# Feature 485/512 - Importance: -0.0006
# Feature 486/512 - Importance: -0.0000
# Feature 487/512 - Importance: 0.0001
# Feature 488/512 - Importance: -0.0013
# Feature 489/512 - Importance: -0.0066
# Feature 490/512 - Importance: -0.0027
# Feature 491/512 - Importance: 0.0025
# Feature 492/512 - Importance: -0.0010
# Feature 493/512 - Importance: -0.0001
# Feature 494/512 - Importance: -0.0008
# Feature 495/512 - Importance: -0.0002
# Feature 496/512 - Importance: -0.0056
# Feature 497/512 - Importance: -0.0022
# Feature 498/512 - Importance: 0.0005
# Feature 499/512 - Importance: -0.0018
# Feature 500/512 - Importance: 0.0236
# Feature 501/512 - Importance: 0.0092
# Feature 502/512 - Importance: -0.0020
# Feature 503/512 - Importance: -0.0012
# Feature 504/512 - Importance: 0.0006
# Feature 505/512 - Importance: 0.0028
# Feature 506/512 - Importance: 0.0005
# Feature 507/512 - Importance: -0.0008
# Feature 508/512 - Importance: 0.0078
# Feature 509/512 - Importance: 0.0013
# Feature 510/512 - Importance: 0.0011
# Feature 511/512 - Importance: 0.0024
# Feature 512/512 - Importance: 0.0048

# %%
positiveFeatures_toucan, negativeFeatures_toucan = positive_negative_features(importance_dict_toucan)
# Out:
# Il y a 270 features positives et 242 features négatives.

# %%
positiveFeatures_hornbill, negativeFeatures_hornbill = positive_negative_features(importance_dict_hornbill)
# Out:
# Il y a 250 features positives et 262 features négatives.

# %%
def categorize_indices(dict1, dict2):
    both_pos_or_null = []
    both_neg = []
    first_pos_second_neg = []
    first_neg_second_pos = []

    all_keys = set(dict1.keys()).union(set(dict2.keys()))

    for key in all_keys:
        score1 = dict1.get(key, 0)
        score2 = dict2.get(key, 0)

        if score1 >= 0 and score2 >= 0:
            both_pos_or_null.append(key)
        elif score1 < 0 and score2 < 0:
            both_neg.append(key)
        elif score1 >= 0 and score2 < 0:
            first_pos_second_neg.append(key)
        elif score1 < 0 and score2 >= 0:
            first_neg_second_pos.append(key)

    return both_pos_or_null, both_neg, first_pos_second_neg, first_neg_second_pos

res = categorize_indices(importance_dict_toucan, importance_dict_hornbill)
print("Les IDX avec score positif ou nul pour les deux :", res[0])
print("Les IDX avec score négatif pour les deux :", res[1])
print("Les IDX avec premier positif ou nul et deuxième négatif :", res[2])
print("Les IDX avec premier négatif et deuxième positif ou nul :", res[3])
# Out:
# Les IDX avec score positif ou nul pour les deux : [1, 4, 14, 15, 18, 25, 27, 30, 33, 37, 40, 44, 51, 54, 60, 62, 74, 83, 87, 97, 98, 101, 104, 106, 107, 111, 121, 122, 125, 129, 135, 139, 149, 152, 153, 154, 155, 157, 159, 167, 168, 172, 184, 186, 188, 191, 192, 194, 196, 200, 204, 211, 226, 234, 246, 249, 255, 257, 269, 271, 272, 276, 280, 281, 283, 296, 298, 301, 305, 310, 311, 312, 313, 318, 325, 328, 331, 332, 337, 340, 344, 351, 355, 357, 367, 377, 380, 381, 392, 398, 399, 402, 417, 420, 421, 430, 432, 440, 442, 446, 469, 471, 474, 476, 477, 483, 500, 503, 504, 507, 511]
# Les IDX avec score négatif pour les deux : [0, 2, 5, 6, 8, 11, 17, 22, 28, 49, 50, 59, 64, 67, 71, 72, 85, 92, 103, 108, 109, 120, 123, 124, 127, 131, 142, 147, 156, 169, 170, 175, 180, 185, 189, 190, 198, 201, 202, 212, 214, 215, 217, 219, 222, 224, 227, 228, 238, 241, 254, 258, 260, 261, 264, 268, 273, 274, 279, 289, 293, 308, 317, 324, 329, 335, 346, 348, 354, 358, 361, 363, 371, 379, 382, 383, 393, 413, 414, 422, 423, 425, 427, 428, 429, 433, 436, 438, 443, 450, 451, 454, 456, 459, 466, 473, 475, 479, 481, 485, 491, 492, 494]
# Les IDX avec premier positif ou nul et deuxième négatif : [7, 20, 23, 24, 29, 31, 32, 34, 35, 36, 38, 39, 42, 43, 47, 48, 53, 55, 56, 57, 58, 63, 65, 66, 68, 69, 76, 82, 86, 90, 91, 93, 96, 105, 110, 112, 115, 116, 117, 119, 128, 130, 132, 133, 134, 137, 140, 141, 144, 145, 146, 148, 150, 151, 158, 161, 165, 166, 171, 177, 181, 182, 187, 207, 209, 213, 216, 218, 221, 225, 232, 233, 235, 236, 242, 243, 244, 251, 253, 262, 263, 265, 266, 270, 275, 277, 282, 285, 291, 292, 300, 303, 304, 306, 307, 309, 316, 320, 333, 339, 341, 347, 349, 350, 362, 368, 370, 372, 373, 376, 378, 386, 387, 388, 390, 391, 394, 396, 400, 401, 403, 404, 405, 406, 407, 408, 410, 416, 419, 424, 426, 431, 435, 439, 441, 444, 447, 448, 452, 457, 462, 463, 464, 468, 470, 472, 478, 482, 484, 487, 488, 489, 493, 495, 496, 498, 501, 502, 506]
# Les IDX avec premier négatif et deuxième positif ou nul : [3, 9, 10, 12, 13, 16, 19, 21, 26, 41, 45, 46, 52, 61, 70, 73, 75, 77, 78, 79, 80, 81, 84, 88, 89, 94, 95, 99, 100, 102, 113, 114, 118, 126, 136, 138, 143, 160, 162, 163, 164, 173, 174, 176, 178, 179, 183, 193, 195, 197, 199, 203, 205, 206, 208, 210, 220, 223, 229, 230, 231, 237, 239, 240, 245, 247, 248, 250, 252, 256, 259, 267, 278, 284, 286, 287, 288, 290, 294, 295, 297, 299, 302, 314, 315, 319, 321, 322, 323, 326, 327, 330, 334, 336, 338, 342, 343, 345, 352, 353, 356, 359, 360, 364, 365, 366, 369, 374, 375, 384, 385, 389, 395, 397, 409, 411, 412, 415, 418, 434, 437, 445, 449, 453, 455, 458, 460, 461, 465, 467, 480, 486, 490, 497, 499, 505, 508, 509, 510]

# %%
#number in each list
print(f"both_pos_or_null : {len(res[0])}")
print(f"both_neg : {len(res[1])}")
print(f"first_pos_second_neg : {len(res[2])}")
print(f"first_neg_second_pos : {len(res[3])}")
# Out:
# both_pos_or_null : 111
# both_neg : 103
# first_pos_second_neg : 159
# first_neg_second_pos : 139
